# %% [markdown]
# <a href="https://colab.research.google.com/github/IvoZal/pytorch-deep-learning-my-fork/blob/main/extras/exercises/04_pytorch_custom_datasets_exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 04. PyTorch Custom Datasets Exercises Template
#
# Welcome to the 04. PyTorch Custom Datasets exercise template.
#
# The best way to practice PyTorch code is to write more PyTorch code.
#
# So read the original notebook and try to complete the exercises by writing code where it's required.
#
# Feel free to reference the original resources whenever you need but should practice writing all of the code yourself.
#
# ## Resources
#
# 1. These exercises/solutions are based on [notebook 04 of the Learn PyTorch for Deep Learning course](https://www.learnpytorch.io/04_pytorch_custom_datasets/).
# 2. See a live [walkthrough of the solutions (errors and all) on YouTube](https://youtu.be/vsFMF9wqWx0).
# 3. See [other solutions on the course GitHub](https://github.com/mrdbourke/pytorch-deep-learning/tree/main/extras/solutions).

# %%
# Check for GPU
# !nvidia-smi
# Out:
# Fri Apr 25 05:01:05 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   66C    P8             13W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
# Import torch
import torch
from torch import nn

# Exercises require PyTorch > 1.10.0
print(torch.__version__)

# Setup device agnostic code
device = "cuda" if torch.cuda.is_available() else "cpu"
device
# Out:
# 2.6.0+cu124
# 'cuda'

# %% [markdown]
# ## 1. Our models are underperforming (not fitting the data well). What are 3 methods for preventing underfitting? Write them down and explain each with a sentence.

# %% [markdown]
# ## 2. Recreate the data loading functions we built in [sections 1, 2, 3 and 4 of notebook 04](https://www.learnpytorch.io/04_pytorch_custom_datasets/). You should have train and test `DataLoader`'s ready to use.

# %%
# 1. Get data
import requests
import zipfile
from pathlib import Path

# Setup path to data folder
data_path = Path("data/")
image_path = data_path / "pizza_steak_sushi"

# If the image folder doesn't exist, download it and prepare it...
if image_path.is_dir():
    print(f"{image_path} directory exists.")
else:
    print(f"Did not find {image_path} directory, creating one...")
    image_path.mkdir(parents=True, exist_ok=True)

    # Download pizza, steak, sushi data
    with open(data_path / "pizza_steak_sushi.zip", "wb") as f:
        request = requests.get("https://github.com/mrdbourke/pytorch-deep-learning/raw/main/data/pizza_steak_sushi.zip")
        print("Downloading pizza, steak, sushi data...")
        f.write(request.content)

    # Unzip pizza, steak, sushi data
    with zipfile.ZipFile(data_path / "pizza_steak_sushi.zip", "r") as zip_ref:
        print("Unzipping pizza, steak, sushi data...")
        zip_ref.extractall(image_path)
# Out:
# Did not find data/pizza_steak_sushi directory, creating one...
# Downloading pizza, steak, sushi data...
# Unzipping pizza, steak, sushi data...

# %%
# 2. Become one with the data
import os
def walk_through_dir(dir_path):
  """Walks through dir_path returning file counts of its contents."""
  for dirpath, dirnames, filenames in os.walk(dir_path):
    print(f"There are {len(dirnames)} directories and {len(filenames)} images in '{dirpath}'.")

walk_through_dir(image_path)
# Out:
# There are 2 directories and 0 images in 'data/pizza_steak_sushi'.
# There are 3 directories and 0 images in 'data/pizza_steak_sushi/test'.
# There are 0 directories and 31 images in 'data/pizza_steak_sushi/test/sushi'.
# There are 0 directories and 19 images in 'data/pizza_steak_sushi/test/steak'.
# There are 0 directories and 25 images in 'data/pizza_steak_sushi/test/pizza'.
# There are 3 directories and 0 images in 'data/pizza_steak_sushi/train'.
# There are 0 directories and 72 images in 'data/pizza_steak_sushi/train/sushi'.
# There are 0 directories and 75 images in 'data/pizza_steak_sushi/train/steak'.
# There are 0 directories and 78 images in 'data/pizza_steak_sushi/train/pizza'.

# %%
# Setup train and testing paths
train_path = image_path / 'train'
test_path = image_path / 'test'

train_path, test_path
# Out:
# (PosixPath('data/pizza_steak_sushi/train'),
#  PosixPath('data/pizza_steak_sushi/test'))

# %%
# Visualize an image
import random
from PIL import Image

img_list = list(image_path.glob("*/*/*.jpg"))

random_img_path = random.choice(img_list)

random_img_class = random_img_path.parent.stem

random_img = Image.open(random_img_path)

print(f"Image class: {random_img_class}")
random_img
# Out:
# Image class: steak
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>

# %%
# Do the image visualization with matplotlib

# %% [markdown]
# We've got some images in our folders.
#
# Now we need to make them compatible with PyTorch by:
# 1. Transform the data into tensors.
# 2. Turn the tensor data into a `torch.utils.data.Dataset` and later a `torch.utils.data.DataLoader`.

# %%
# 3.1 Transforming data with torchvision.transforms
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, datasets

# %%
# Write transform for turning images into tensors
transform_to_tensor = transforms.Compose([
    transforms.Resize(size=(64, 64)),
    transforms.ToTensor()
])

# %%
# Write a function to plot transformed images
import matplotlib.pyplot as plt

def plot_img_tf(image_path, transform):
  img_list = list(image_path.glob("*/*.jpg"))

  random_img_path = random.choice(img_list)

  with Image.open(random_img_path) as img:
    fig, ax = plt.subplots(1, 2)

    ax[0].set_title("Original image")
    ax[0].imshow(img)
    ax[0].axis("off")

    transformed_img = transform(img).permute(1, 2, 0)

    ax[1].set_title("Transformed image")
    ax[1].imshow(transformed_img)
    ax[1].axis("off")

plot_img_tf(test_path, transform_to_tensor)

# %% [markdown]
# ### Load image data using `ImageFolder`

# %%
# Use ImageFolder to create dataset(s)
from torchvision import datasets

train_data = datasets.ImageFolder(root=train_path,
                                  transform=transform_to_tensor)

test_data = datasets.ImageFolder(root=test_path,
                                 transform=transform_to_tensor)

print(f"Train data:\n{train_data}\nTest data:\n{test_data}")
# Out:
# Train data:
# Dataset ImageFolder
#     Number of datapoints: 225
#     Root location: data/pizza_steak_sushi/train
#     StandardTransform
# Transform: Compose(
#                Resize(size=(64, 64), interpolation=bilinear, max_size=None, antialias=True)
#                ToTensor()
#            )
# Test data:
# Dataset ImageFolder
#     Number of datapoints: 75
#     Root location: data/pizza_steak_sushi/test
#     StandardTransform
# Transform: Compose(
#                Resize(size=(64, 64), interpolation=bilinear, max_size=None, antialias=True)
#                ToTensor()
#            )

# %%
# Get class names as a list
class_names = train_data.classes
class_names
# Out:
# ['pizza', 'steak', 'sushi']

# %%
# Can also get class names as a dict
class_dict = train_data.class_to_idx
class_dict
# Out:
# {'pizza': 0, 'steak': 1, 'sushi': 2}

# %%
# Check the lengths of each dataset
len(train_data), len(test_data)
# Out:
# (225, 75)

# %%
# Turn train and test Datasets into DataLoaders
train_dataloader = DataLoader(train_data, batch_size=32, shuffle=True)
test_dataloader = DataLoader(test_data, batch_size=32, shuffle=False)

train_dataloader, test_dataloader
# Out:
# (<torch.utils.data.dataloader.DataLoader at 0x7d4183857d90>,
#  <torch.utils.data.dataloader.DataLoader at 0x7d41838504d0>)

# %%
# How many batches of images are in our data loaders?
print(f"Number of train batches: {len(train_dataloader)}")
print(f"Number of test batches: {len(test_dataloader)}")
# Out:
# Number of train batches: 8
# Number of test batches: 3

# %% [markdown]
# ## 3. Recreate `model_0` we built in section 7 of notebook 04.

# %%
class TinyVGG(nn.Module):
  def __init__(self, input_shape: int, hidden_units: int, output_shape: int):
    super().__init__()
    self.conv_block_1 = nn.Sequential(
        nn.Conv2d(in_channels=input_shape,
                  out_channels=hidden_units,
                  kernel_size=3,
                  padding=1),
        nn.ReLU(),
        nn.Conv2d(in_channels=hidden_units,
                  out_channels=hidden_units,
                  kernel_size=3,
                  padding=1),
        nn.ReLU(),
        nn.MaxPool2d(kernel_size=2)
    )

    self.conv_block_2 = nn.Sequential(
        nn.Conv2d(in_channels=hidden_units,
                  out_channels=hidden_units,
                  kernel_size=3,
                  padding=1),
        nn.ReLU(),
        nn.Conv2d(in_channels=hidden_units,
                  out_channels=hidden_units,
                  kernel_size=3,
                  padding=1),
        nn.ReLU(),
        nn.MaxPool2d(kernel_size=2)
    )

    self.classifier = nn.Sequential(
        nn.Flatten(),
        nn.Linear(in_features=hidden_units*16*16,
                  out_features=output_shape)
    )

  def forward(self, x: torch.Tensor):
    return self.classifier(self.conv_block_2(self.conv_block_1(x)))

model_0 = TinyVGG(input_shape=3,
                  hidden_units=10,
                  output_shape=len(train_data.classes)
                  ).to(device)

model_0
# Out:
# TinyVGG(
#   (conv_block_1): Sequential(
#     (0): Conv2d(3, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(10, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv_block_2): Sequential(
#     (0): Conv2d(10, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(10, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=2560, out_features=3, bias=True)
#   )
# )

# %% [markdown]
# ## 4. Create training and testing functions for `model_0`.

# %%
def train_step(model: torch.nn.Module,
               dataloader: torch.utils.data.DataLoader,
               loss_fn: torch.nn.Module,
               optimizer: torch.optim.Optimizer):

  # Put the model in train mode
  model.train()

  # Setup train loss and train accuracy values
  train_loss, train_acc = 0, 0

  # Loop through data loader and data batches
  for batch, (X, y) in enumerate(dataloader):
    # Send data to target device
    X, y = X.to(device), y.to(device)

    # 1. Forward pass
    y_pred = model(X)

    # 2. Calculate and accumulate loss
    loss = loss_fn(y_pred, y)
    train_loss += loss.item()

    # 3. Optimizer zero grad
    optimizer.zero_grad()

    # 4. Loss backward
    loss.backward()

    # 5. Optimizer step
    optimizer.step()

    # Calculate and accumualte accuracy metric across all batches
    y_pred_class = torch.argmax(torch.softmax(y_pred, dim=1), dim=1)
    train_acc += (y_pred_class == y).sum().item() / len(y_pred)

  # Adjust metrics to get average loss and average accuracy per batch
  train_loss = train_loss / len(dataloader)
  train_acc = train_acc / len(dataloader)

  return train_loss, train_acc

# %%
def test_step(model: torch.nn.Module,
              dataloader: torch.utils.data.DataLoader,
              loss_fn: torch.nn.Module):

  # Put model in eval mode
  model.eval()

  # Setup the test loss and test accuracy values
  test_loss, test_acc = 0, 0

  # Turn on inference context manager
  with torch.inference_mode():
    # Loop through DataLoader batches
    for batch, (X, y) in enumerate(dataloader):
      # Send data to target device
      X, y = X.to(device), y.to(device)

      # 1. Forward pass
      y_pred = model(X)

      # 2. Calculuate and accumulate loss
      loss = loss_fn(y_pred, y)
      test_loss += loss.item()

      # Calculate and accumulate accuracy
      test_pred_class = y_pred.argmax(dim=1)
      test_acc += (test_pred_class == y).sum().item() / len(test_pred_class)

  # Adjust metrics to get average loss and accuracy per batch
  test_loss = test_loss / len(dataloader)
  test_acc = test_acc / len(dataloader)

  return test_loss, test_acc

# %%
from tqdm.auto import tqdm

def train(model: torch.nn.Module,
          train_dataloader: torch.utils.data.DataLoader,
          test_dataloader: torch.utils.data.DataLoader,
          optimizer: torch.optim.Optimizer,
          loss_fn: torch.nn.Module = nn.CrossEntropyLoss(),
          epochs: int = 5):

  # Create results dictionary
  results = {"train_loss": [],
             "train_acc": [],
             "test_loss": [],
             "test_acc": []}

  # Loop through the training and testing steps for a number of epochs
  for epoch in tqdm(range(epochs)):
    # Train step
    train_loss, train_acc = train_step(model=model,
                                       dataloader=train_dataloader,
                                       loss_fn=loss_fn,
                                       optimizer=optimizer)
    # Test step
    test_loss, test_acc = test_step(model=model,
                                    dataloader=test_dataloader,
                                    loss_fn=loss_fn)

    # Print out what's happening
    print(f"Epoch: {epoch+1} | "
          f"train_loss: {train_loss:.4f} | "
          f"train_acc: {train_acc:.4f} | "
          f"test_loss: {test_loss:.4f} | "
          f"test_acc: {test_acc:.4f}"
    )

    # Update the results dictionary
    results["train_loss"].append(train_loss)
    results["train_acc"].append(train_acc)
    results["test_loss"].append(test_loss)
    results["test_acc"].append(test_acc)

  # Return the results dictionary
  return results

# %% [markdown]
# ## 5. Try training the model you made in exercise 3 for 5, 20 and 50 epochs, what happens to the results?
# * Use `torch.optim.Adam()` with a learning rate of 0.001 as the optimizer.

# %%
# Train for 5 epochs
torch.manual_seed(42)
torch.cuda.manual_seed(42)

NUM_EPOCHS=5

loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model_0.parameters(),
                             lr=0.001)

model_0_results = train(model=model_0,
                        train_dataloader=train_dataloader,
                        test_dataloader=test_dataloader,
                        optimizer=optimizer,
                        loss_fn=loss_fn,
                        epochs=NUM_EPOCHS)
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# Epoch: 1 | train_loss: 1.1060 | train_acc: 0.2852 | test_loss: 1.1080 | test_acc: 0.2604
# Epoch: 2 | train_loss: 1.0775 | train_acc: 0.4258 | test_loss: 1.1338 | test_acc: 0.2604
# Epoch: 3 | train_loss: 1.0746 | train_acc: 0.4258 | test_loss: 1.1560 | test_acc: 0.2604
# Epoch: 4 | train_loss: 1.0805 | train_acc: 0.3047 | test_loss: 1.1227 | test_acc: 0.2917
# Epoch: 5 | train_loss: 1.0549 | train_acc: 0.4180 | test_loss: 1.0752 | test_acc: 0.3532

# %%
# Train for 20 epochs
torch.manual_seed(42)
torch.cuda.manual_seed(42)

loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(#TODO,
                             lr=0.001)

# %%
# Train for 50 epochs
torch.manual_seed(42)
torch.cuda.manual_seed(42)

NUM_EPOCHS=50

loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model_0.parameters(),
                             lr=0.001)

model_0_results = train(model=model_0,
                        train_dataloader=train_dataloader,
                        test_dataloader=test_dataloader,
                        optimizer=optimizer,
                        loss_fn=loss_fn,
                        epochs=NUM_EPOCHS)
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# Epoch: 1 | train_loss: 0.9645 | train_acc: 0.5703 | test_loss: 1.0497 | test_acc: 0.3011
# Epoch: 2 | train_loss: 0.9300 | train_acc: 0.5898 | test_loss: 1.0638 | test_acc: 0.3731
# Epoch: 3 | train_loss: 0.8760 | train_acc: 0.6094 | test_loss: 1.0168 | test_acc: 0.4034
# Epoch: 4 | train_loss: 0.7749 | train_acc: 0.6445 | test_loss: 0.9935 | test_acc: 0.4744
# Epoch: 5 | train_loss: 0.7984 | train_acc: 0.6797 | test_loss: 1.0538 | test_acc: 0.3617
# Epoch: 6 | train_loss: 0.8273 | train_acc: 0.6211 | test_loss: 1.1007 | test_acc: 0.4129
# Epoch: 7 | train_loss: 0.8112 | train_acc: 0.6133 | test_loss: 1.0567 | test_acc: 0.3826
# Epoch: 8 | train_loss: 0.8083 | train_acc: 0.6641 | test_loss: 1.0076 | test_acc: 0.5256
# Epoch: 9 | train_loss: 0.8944 | train_acc: 0.5352 | test_loss: 1.0007 | test_acc: 0.5047
# Epoch: 10 | train_loss: 0.8461 | train_acc: 0.4922 | test_loss: 0.9325 | test_acc: 0.5227
# Epoch: 11 | train_loss: 0.7571 | train_acc: 0.6758 | test_loss: 1.0626 | test_acc: 0.3324
# Epoch: 12 | train_loss: 0.7575 | train_acc: 0.6289 | test_loss: 1.0952 | test_acc: 0.3210
# Epoch: 13 | train_loss: 0.7500 | train_acc: 0.7227 | test_loss: 1.0123 | test_acc: 0.4129
# Epoch: 14 | train_loss: 0.7292 | train_acc: 0.7188 | test_loss: 1.0322 | test_acc: 0.4223
# Epoch: 15 | train_loss: 0.7928 | train_acc: 0.6172 | test_loss: 1.1592 | test_acc: 0.4129
# Epoch: 16 | train_loss: 0.6959 | train_acc: 0.7031 | test_loss: 1.0420 | test_acc: 0.5246
# Epoch: 17 | train_loss: 0.6492 | train_acc: 0.7695 | test_loss: 1.1581 | test_acc: 0.4044
# Epoch: 18 | train_loss: 0.6849 | train_acc: 0.7578 | test_loss: 1.1320 | test_acc: 0.3939
# Epoch: 19 | train_loss: 0.6526 | train_acc: 0.7305 | test_loss: 1.1172 | test_acc: 0.4223
# Epoch: 20 | train_loss: 0.6346 | train_acc: 0.7695 | test_loss: 1.0487 | test_acc: 0.4631
# Epoch: 21 | train_loss: 0.5962 | train_acc: 0.7891 | test_loss: 1.1310 | test_acc: 0.4233
# Epoch: 22 | train_loss: 0.6942 | train_acc: 0.6211 | test_loss: 1.0391 | test_acc: 0.5028
# Epoch: 23 | train_loss: 0.6219 | train_acc: 0.6875 | test_loss: 1.0512 | test_acc: 0.4337
# Epoch: 24 | train_loss: 0.6489 | train_acc: 0.6211 | test_loss: 1.1203 | test_acc: 0.3627
# Epoch: 25 | train_loss: 0.6727 | train_acc: 0.7578 | test_loss: 0.9779 | test_acc: 0.4725
# Epoch: 26 | train_loss: 0.7125 | train_acc: 0.6328 | test_loss: 1.1491 | test_acc: 0.3333
# Epoch: 27 | train_loss: 0.7241 | train_acc: 0.6094 | test_loss: 1.0923 | test_acc: 0.3835
# Epoch: 28 | train_loss: 0.5799 | train_acc: 0.8047 | test_loss: 1.0198 | test_acc: 0.4631
# Epoch: 29 | train_loss: 0.6455 | train_acc: 0.6445 | test_loss: 0.9908 | test_acc: 0.4735
# Epoch: 30 | train_loss: 0.6112 | train_acc: 0.6992 | test_loss: 1.0185 | test_acc: 0.4441
# Epoch: 31 | train_loss: 0.5100 | train_acc: 0.8516 | test_loss: 1.0861 | test_acc: 0.3920
# Epoch: 32 | train_loss: 0.4498 | train_acc: 0.8359 | test_loss: 1.3538 | test_acc: 0.3835
# Epoch: 33 | train_loss: 0.4887 | train_acc: 0.8398 | test_loss: 1.2093 | test_acc: 0.4129
# Epoch: 34 | train_loss: 0.4105 | train_acc: 0.8711 | test_loss: 1.3678 | test_acc: 0.3419
# Epoch: 35 | train_loss: 0.7780 | train_acc: 0.7383 | test_loss: 1.2484 | test_acc: 0.4223
# Epoch: 36 | train_loss: 0.6818 | train_acc: 0.6758 | test_loss: 1.3119 | test_acc: 0.4328
# Epoch: 37 | train_loss: 0.7930 | train_acc: 0.6250 | test_loss: 1.1055 | test_acc: 0.4735
# Epoch: 38 | train_loss: 0.5230 | train_acc: 0.7891 | test_loss: 1.0603 | test_acc: 0.5559
# Epoch: 39 | train_loss: 0.4427 | train_acc: 0.8477 | test_loss: 1.2409 | test_acc: 0.4555
# Epoch: 40 | train_loss: 0.4179 | train_acc: 0.8555 | test_loss: 1.1412 | test_acc: 0.4744
# Epoch: 41 | train_loss: 0.3417 | train_acc: 0.8906 | test_loss: 1.1531 | test_acc: 0.4943
# Epoch: 42 | train_loss: 0.3217 | train_acc: 0.9180 | test_loss: 1.2460 | test_acc: 0.4536
# Epoch: 43 | train_loss: 0.2739 | train_acc: 0.9023 | test_loss: 1.3381 | test_acc: 0.4536
# Epoch: 44 | train_loss: 0.2211 | train_acc: 0.9219 | test_loss: 1.3543 | test_acc: 0.4943
# Epoch: 45 | train_loss: 0.1938 | train_acc: 0.9453 | test_loss: 1.4302 | test_acc: 0.5047
# Epoch: 46 | train_loss: 0.1936 | train_acc: 0.9453 | test_loss: 1.4789 | test_acc: 0.5038
# Epoch: 47 | train_loss: 0.1545 | train_acc: 0.9570 | test_loss: 1.6479 | test_acc: 0.5152
# Epoch: 48 | train_loss: 0.1360 | train_acc: 0.9492 | test_loss: 1.6583 | test_acc: 0.5152
# Epoch: 49 | train_loss: 0.1160 | train_acc: 0.9688 | test_loss: 1.8668 | test_acc: 0.4848
# Epoch: 50 | train_loss: 0.0998 | train_acc: 0.9727 | test_loss: 1.7722 | test_acc: 0.5246

# %% [markdown]
# It looks like our model is starting to overfit towards the end (performing far better on the training data than on the testing data).
#
# In order to fix this, we'd have to introduce ways of preventing overfitting.

# %% [markdown]
# ## 6. Double the number of hidden units in your model and train it for 20 epochs, what happens to the results?

# %%
# Double the number of hidden units and train for 20 epochs
torch.manual_seed(42)
torch.cuda.manual_seed(42)

model_1 = TinyVGG(3, 20, len(train_data.classes)).to(device)

NUM_EPOCHS=20

loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model_1.parameters(),
                             lr=0.001)

model_1_results = train(model=model_1,
                        train_dataloader=train_dataloader,
                        test_dataloader=test_dataloader,
                        optimizer=optimizer,
                        loss_fn=loss_fn,
                        epochs=NUM_EPOCHS)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch: 1 | train_loss: 1.1074 | train_acc: 0.4180 | test_loss: 1.1063 | test_acc: 0.2604
# Epoch: 2 | train_loss: 1.1267 | train_acc: 0.3047 | test_loss: 1.1017 | test_acc: 0.2604
# Epoch: 3 | train_loss: 1.0948 | train_acc: 0.3164 | test_loss: 1.0967 | test_acc: 0.3949
# Epoch: 4 | train_loss: 1.0930 | train_acc: 0.4297 | test_loss: 1.0723 | test_acc: 0.5833
# Epoch: 5 | train_loss: 1.0587 | train_acc: 0.5508 | test_loss: 1.0308 | test_acc: 0.5038
# Epoch: 6 | train_loss: 0.9856 | train_acc: 0.5820 | test_loss: 1.1296 | test_acc: 0.3125
# Epoch: 7 | train_loss: 1.0204 | train_acc: 0.4688 | test_loss: 0.9161 | test_acc: 0.5331
# Epoch: 8 | train_loss: 0.9004 | train_acc: 0.6016 | test_loss: 1.0700 | test_acc: 0.3333
# Epoch: 9 | train_loss: 0.8802 | train_acc: 0.4883 | test_loss: 0.9921 | test_acc: 0.3428
# Epoch: 10 | train_loss: 0.9531 | train_acc: 0.5234 | test_loss: 0.9802 | test_acc: 0.5133
# Epoch: 11 | train_loss: 0.8958 | train_acc: 0.5781 | test_loss: 1.0148 | test_acc: 0.3835
# Epoch: 12 | train_loss: 0.9475 | train_acc: 0.4766 | test_loss: 1.0132 | test_acc: 0.3835
# Epoch: 13 | train_loss: 0.8714 | train_acc: 0.5352 | test_loss: 0.9192 | test_acc: 0.5947
# Epoch: 14 | train_loss: 0.9416 | train_acc: 0.5312 | test_loss: 0.9464 | test_acc: 0.5350
# Epoch: 15 | train_loss: 0.9613 | train_acc: 0.5977 | test_loss: 0.9262 | test_acc: 0.5653
# Epoch: 16 | train_loss: 0.7406 | train_acc: 0.6914 | test_loss: 1.0172 | test_acc: 0.4631
# Epoch: 17 | train_loss: 0.7907 | train_acc: 0.6055 | test_loss: 1.0356 | test_acc: 0.4148
# Epoch: 18 | train_loss: 0.7380 | train_acc: 0.6953 | test_loss: 1.0463 | test_acc: 0.4242
# Epoch: 19 | train_loss: 0.6656 | train_acc: 0.6875 | test_loss: 1.0577 | test_acc: 0.5455
# Epoch: 20 | train_loss: 0.6703 | train_acc: 0.7383 | test_loss: 1.0336 | test_acc: 0.4536

# %% [markdown]
# It looks like the model is still overfitting, even when changing the number of hidden units.
#
# To fix this, we'd have to look at ways to prevent overfitting with our model.

# %% [markdown]
# ## 7. Double the data you're using with your model from step 6 and train it for 20 epochs, what happens to the results?
# * **Note:** You can use the [custom data creation notebook](https://github.com/mrdbourke/pytorch-deep-learning/blob/main/extras/04_custom_data_creation.ipynb) to scale up your Food101 dataset.
# * You can also find the [already formatted double data (20% instead of 10% subset) dataset on GitHub](https://github.com/mrdbourke/pytorch-deep-learning/blob/main/data/pizza_steak_sushi_20_percent.zip), you will need to write download code like in exercise 2 to get it into this notebook.

# %%
# Download 20% data for Pizza/Steak/Sushi from GitHub
import requests
import zipfile
from pathlib import Path

# Setup path to data folder
data_path = Path("data/")
image_path = data_path / "pizza_steak_sushi_20_percent"

# If the image folder doesn't exist, download it and prepare it...
if image_path.is_dir():
    print(f"{image_path} directory exists.")
else:
    print(f"Did not find {image_path} directory, creating one...")
    image_path.mkdir(parents=True, exist_ok=True)

# Download pizza, steak, sushi data
with open(data_path / "pizza_steak_sushi_20_percent.zip", "wb") as f:
    request = requests.get("https://github.com/mrdbourke/pytorch-deep-learning/raw/main/data/pizza_steak_sushi_20_percent.zip")
    print("Downloading pizza, steak, sushi 20% data...")
    f.write(request.content)

# Unzip pizza, steak, sushi data
with zipfile.ZipFile(data_path / "pizza_steak_sushi_20_percent.zip", "r") as zip_ref:
    print("Unzipping pizza, steak, sushi 20% data...")
    zip_ref.extractall(image_path)
# Out:
# data/pizza_steak_sushi_20_percent directory exists.
# Downloading pizza, steak, sushi 20% data...
# Unzipping pizza, steak, sushi 20% data...

# %%
# See how many images we have
walk_through_dir(image_path)
# Out:
# There are 2 directories and 0 images in 'data/pizza_steak_sushi_20_percent'.
# There are 3 directories and 0 images in 'data/pizza_steak_sushi_20_percent/test'.
# There are 0 directories and 46 images in 'data/pizza_steak_sushi_20_percent/test/sushi'.
# There are 0 directories and 58 images in 'data/pizza_steak_sushi_20_percent/test/steak'.
# There are 0 directories and 46 images in 'data/pizza_steak_sushi_20_percent/test/pizza'.
# There are 3 directories and 0 images in 'data/pizza_steak_sushi_20_percent/train'.
# There are 0 directories and 150 images in 'data/pizza_steak_sushi_20_percent/train/sushi'.
# There are 0 directories and 146 images in 'data/pizza_steak_sushi_20_percent/train/steak'.
# There are 0 directories and 154 images in 'data/pizza_steak_sushi_20_percent/train/pizza'.

# %% [markdown]
# Excellent, we now have double the training and testing images...

# %%
# Create the train and test paths
train_data_20_percent_path = image_path / "train"
test_data_20_percent_path = image_path / "test"

train_data_20_percent_path, test_data_20_percent_path
# Out:
# (PosixPath('data/pizza_steak_sushi_20_percent/train'),
#  PosixPath('data/pizza_steak_sushi_20_percent/test'))

# %%
# Turn the 20 percent datapaths into Datasets and DataLoaders
from torchvision.datasets import ImageFolder
from torchvision import transforms
from torch.utils.data import DataLoader

simple_transform = transforms.Compose([
  transforms.Resize((64, 64)),
  transforms.ToTensor()
])

# Create datasets
train_data_20_percent = ImageFolder(root=train_data_20_percent_path,
                        transform=simple_transform)

test_data_20_percent = ImageFolder(root=test_data_20_percent_path,
                        transform=simple_transform)

print(f"Train data:\n{train_data_20_percent}\nTest data:\n{test_data_20_percent}")

# Create dataloaders
train_loader_20_percent = DataLoader(train_data_20_percent,
                                     batch_size=32,
                                     shuffle=True)

test_loader_20_percent = DataLoader(test_data_20_percent,
                                     batch_size=32,
                                     shuffle=True)
# Out:
# Train data:
# Dataset ImageFolder
#     Number of datapoints: 450
#     Root location: data/pizza_steak_sushi_20_percent/train
#     StandardTransform
# Transform: Compose(
#                Resize(size=(64, 64), interpolation=bilinear, max_size=None, antialias=True)
#                ToTensor()
#            )
# Test data:
# Dataset ImageFolder
#     Number of datapoints: 150
#     Root location: data/pizza_steak_sushi_20_percent/test
#     StandardTransform
# Transform: Compose(
#                Resize(size=(64, 64), interpolation=bilinear, max_size=None, antialias=True)
#                ToTensor()
#            )

# %%
# Train a model with increased amount of data
torch.manual_seed(42)
torch.cuda.manual_seed(42)

model_1_results = train(model=model_1,
                        train_dataloader=train_loader_20_percent,
                        test_dataloader=test_loader_20_percent,
                        optimizer=optimizer,
                        loss_fn=loss_fn,
                        epochs=NUM_EPOCHS)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch: 1 | train_loss: 0.8125 | train_acc: 0.6687 | test_loss: 0.8424 | test_acc: 0.5591
# Epoch: 2 | train_loss: 0.7854 | train_acc: 0.6792 | test_loss: 0.8453 | test_acc: 0.5869
# Epoch: 3 | train_loss: 0.7748 | train_acc: 0.6667 | test_loss: 0.8275 | test_acc: 0.6432
# Epoch: 4 | train_loss: 0.7627 | train_acc: 0.6500 | test_loss: 0.8228 | test_acc: 0.6114
# Epoch: 5 | train_loss: 0.6975 | train_acc: 0.6875 | test_loss: 0.8910 | test_acc: 0.5932
# Epoch: 6 | train_loss: 0.7035 | train_acc: 0.7083 | test_loss: 0.9726 | test_acc: 0.5534
# Epoch: 7 | train_loss: 0.6607 | train_acc: 0.7125 | test_loss: 0.8321 | test_acc: 0.6108
# Epoch: 8 | train_loss: 0.6459 | train_acc: 0.7229 | test_loss: 0.8580 | test_acc: 0.6080
# Epoch: 9 | train_loss: 0.5181 | train_acc: 0.7917 | test_loss: 0.9176 | test_acc: 0.6119
# Epoch: 10 | train_loss: 0.4948 | train_acc: 0.7688 | test_loss: 1.1172 | test_acc: 0.5528
# Epoch: 11 | train_loss: 0.5459 | train_acc: 0.7625 | test_loss: 1.0084 | test_acc: 0.5784
# Epoch: 12 | train_loss: 0.4086 | train_acc: 0.8313 | test_loss: 1.1058 | test_acc: 0.5653
# Epoch: 13 | train_loss: 0.3714 | train_acc: 0.8583 | test_loss: 1.1644 | test_acc: 0.5966
# Epoch: 14 | train_loss: 0.3164 | train_acc: 0.8875 | test_loss: 1.2791 | test_acc: 0.5994
# Epoch: 15 | train_loss: 0.2492 | train_acc: 0.9062 | test_loss: 1.3915 | test_acc: 0.5898
# Epoch: 16 | train_loss: 0.2556 | train_acc: 0.9125 | test_loss: 1.5954 | test_acc: 0.5460
# Epoch: 17 | train_loss: 0.1985 | train_acc: 0.9313 | test_loss: 1.4928 | test_acc: 0.6040
# Epoch: 18 | train_loss: 0.1522 | train_acc: 0.9542 | test_loss: 1.7760 | test_acc: 0.5443
# Epoch: 19 | train_loss: 0.1415 | train_acc: 0.9563 | test_loss: 2.0348 | test_acc: 0.5534
# Epoch: 20 | train_loss: 0.1349 | train_acc: 0.9542 | test_loss: 2.0961 | test_acc: 0.5807

# %%
# Double the number of hidden units
torch.manual_seed(42)
torch.cuda.manual_seed(42)

model_2 = TinyVGG(3, 40, len(train_data.classes)).to(device)

NUM_EPOCHS=20

loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model_2.parameters(),
                             lr=0.001)

model_2_results = train(model=model_2,
                        train_dataloader=train_loader_20_percent,
                        test_dataloader=test_loader_20_percent,
                        optimizer=optimizer,
                        loss_fn=loss_fn,
                        epochs=NUM_EPOCHS)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch: 1 | train_loss: 1.0902 | train_acc: 0.3854 | test_loss: 1.0362 | test_acc: 0.5188
# Epoch: 2 | train_loss: 0.9272 | train_acc: 0.5854 | test_loss: 0.9932 | test_acc: 0.4716
# Epoch: 3 | train_loss: 0.9265 | train_acc: 0.5188 | test_loss: 0.9507 | test_acc: 0.5250
# Epoch: 4 | train_loss: 0.8707 | train_acc: 0.6000 | test_loss: 0.8798 | test_acc: 0.6085
# Epoch: 5 | train_loss: 0.8268 | train_acc: 0.6542 | test_loss: 0.8558 | test_acc: 0.6142
# Epoch: 6 | train_loss: 0.8612 | train_acc: 0.6146 | test_loss: 0.8872 | test_acc: 0.5398
# Epoch: 7 | train_loss: 0.9009 | train_acc: 0.5375 | test_loss: 0.9397 | test_acc: 0.4477
# Epoch: 8 | train_loss: 0.8121 | train_acc: 0.6396 | test_loss: 0.8650 | test_acc: 0.5835
# Epoch: 9 | train_loss: 0.8270 | train_acc: 0.6125 | test_loss: 0.8399 | test_acc: 0.6148
# Epoch: 10 | train_loss: 0.7635 | train_acc: 0.6542 | test_loss: 0.9159 | test_acc: 0.5278
# Epoch: 11 | train_loss: 0.7797 | train_acc: 0.5979 | test_loss: 0.8298 | test_acc: 0.6028
# Epoch: 12 | train_loss: 0.6891 | train_acc: 0.7125 | test_loss: 0.8185 | test_acc: 0.6182
# Epoch: 13 | train_loss: 0.6502 | train_acc: 0.7521 | test_loss: 1.0702 | test_acc: 0.5000
# Epoch: 14 | train_loss: 0.7022 | train_acc: 0.7063 | test_loss: 0.8720 | test_acc: 0.5949
# Epoch: 15 | train_loss: 0.6327 | train_acc: 0.7146 | test_loss: 0.9296 | test_acc: 0.5869
# Epoch: 16 | train_loss: 0.5809 | train_acc: 0.7667 | test_loss: 0.7953 | test_acc: 0.6375
# Epoch: 17 | train_loss: 0.4634 | train_acc: 0.8187 | test_loss: 1.2332 | test_acc: 0.5869
# Epoch: 18 | train_loss: 0.4446 | train_acc: 0.8250 | test_loss: 0.8604 | test_acc: 0.6369
# Epoch: 19 | train_loss: 0.3407 | train_acc: 0.8625 | test_loss: 1.1385 | test_acc: 0.5687
# Epoch: 20 | train_loss: 0.2875 | train_acc: 0.8917 | test_loss: 1.2686 | test_acc: 0.6210

# %%
# Data augmentation

augmentation_transform = transforms.Compose([
  transforms.RandomHorizontalFlip(),
  transforms.RandomRotation(10),
  transforms.Resize(size=(64, 64)),
  transforms.ToTensor(),
  transforms.Normalize((0.5,), (0.5,))
])

# Create augmented train dataset
train_data_20_percent_aug = ImageFolder(root=train_data_20_percent_path,
                        transform=augmentation_transform)

# Create augmented train dataloader
train_loader_20_percent_aug = DataLoader(train_data_20_percent_aug,
                                     batch_size=32,
                                     shuffle=True)

print(len(train_data_20_percent))
print(len(train_data_20_percent_aug))
# Out:
# 450
# 450

# %%
# Run on augmented dataset
torch.manual_seed(42)
torch.cuda.manual_seed(42)

model_2 = TinyVGG(3, 20, len(train_data.classes)).to(device)

NUM_EPOCHS=40

loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model_2.parameters(),
                             lr=0.001)

model_2_results = train(model=model_2,
                        train_dataloader=train_loader_20_percent_aug,
                        test_dataloader=test_loader_20_percent,
                        optimizer=optimizer,
                        loss_fn=loss_fn,
                        epochs=NUM_EPOCHS)
# Out:
#   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch: 1 | train_loss: 1.0747 | train_acc: 0.4083 | test_loss: 1.1093 | test_acc: 0.2960
# Epoch: 2 | train_loss: 0.9466 | train_acc: 0.5604 | test_loss: 1.1345 | test_acc: 0.3159
# Epoch: 3 | train_loss: 0.8544 | train_acc: 0.5917 | test_loss: 1.0859 | test_acc: 0.4216
# Epoch: 4 | train_loss: 0.8755 | train_acc: 0.6083 | test_loss: 1.0947 | test_acc: 0.3222
# Epoch: 5 | train_loss: 0.8083 | train_acc: 0.6417 | test_loss: 1.0505 | test_acc: 0.3665
# Epoch: 6 | train_loss: 0.8393 | train_acc: 0.6312 | test_loss: 1.1020 | test_acc: 0.4062
# Epoch: 7 | train_loss: 0.8337 | train_acc: 0.6000 | test_loss: 1.2290 | test_acc: 0.3108
# Epoch: 8 | train_loss: 0.8462 | train_acc: 0.6438 | test_loss: 1.0471 | test_acc: 0.5278
# Epoch: 9 | train_loss: 0.7811 | train_acc: 0.6562 | test_loss: 1.1380 | test_acc: 0.4813
# Epoch: 10 | train_loss: 0.7150 | train_acc: 0.6833 | test_loss: 1.0725 | test_acc: 0.4034
# Epoch: 11 | train_loss: 0.7113 | train_acc: 0.6625 | test_loss: 1.1992 | test_acc: 0.4938
# Epoch: 12 | train_loss: 0.7907 | train_acc: 0.6604 | test_loss: 1.4154 | test_acc: 0.4938
# Epoch: 13 | train_loss: 0.7814 | train_acc: 0.6438 | test_loss: 1.2566 | test_acc: 0.4500
# Epoch: 14 | train_loss: 0.6947 | train_acc: 0.6854 | test_loss: 1.2612 | test_acc: 0.4188
# Epoch: 15 | train_loss: 0.6766 | train_acc: 0.7000 | test_loss: 1.1283 | test_acc: 0.4665
# Epoch: 16 | train_loss: 0.6503 | train_acc: 0.7104 | test_loss: 1.3324 | test_acc: 0.4534
# Epoch: 17 | train_loss: 0.6116 | train_acc: 0.6917 | test_loss: 1.3370 | test_acc: 0.4597
# Epoch: 18 | train_loss: 0.6466 | train_acc: 0.7188 | test_loss: 1.1968 | test_acc: 0.4068
# Epoch: 19 | train_loss: 0.6013 | train_acc: 0.7438 | test_loss: 1.1884 | test_acc: 0.4472
# Epoch: 20 | train_loss: 0.5407 | train_acc: 0.7500 | test_loss: 1.5670 | test_acc: 0.4284
# Epoch: 21 | train_loss: 0.5667 | train_acc: 0.7729 | test_loss: 1.2607 | test_acc: 0.4489
# Epoch: 22 | train_loss: 0.5603 | train_acc: 0.7458 | test_loss: 1.2706 | test_acc: 0.3847
# Epoch: 23 | train_loss: 0.6544 | train_acc: 0.7375 | test_loss: 1.1209 | test_acc: 0.4347
# Epoch: 24 | train_loss: 0.5598 | train_acc: 0.7562 | test_loss: 1.2970 | test_acc: 0.3693
# Epoch: 25 | train_loss: 0.5163 | train_acc: 0.8063 | test_loss: 1.2661 | test_acc: 0.4625
# Epoch: 26 | train_loss: 0.4744 | train_acc: 0.7854 | test_loss: 1.3231 | test_acc: 0.4523
# Epoch: 27 | train_loss: 0.4911 | train_acc: 0.7833 | test_loss: 1.7732 | test_acc: 0.3972
# Epoch: 28 | train_loss: 0.4360 | train_acc: 0.8000 | test_loss: 1.2788 | test_acc: 0.4284
# Epoch: 29 | train_loss: 0.4589 | train_acc: 0.8104 | test_loss: 1.2698 | test_acc: 0.4062
# Epoch: 30 | train_loss: 0.4753 | train_acc: 0.8000 | test_loss: 1.4251 | test_acc: 0.4443
# Epoch: 31 | train_loss: 0.4330 | train_acc: 0.8229 | test_loss: 1.1425 | test_acc: 0.4199
# Epoch: 32 | train_loss: 0.4829 | train_acc: 0.7750 | test_loss: 1.3177 | test_acc: 0.3852
# Epoch: 33 | train_loss: 0.5497 | train_acc: 0.7646 | test_loss: 1.2906 | test_acc: 0.3676
# Epoch: 34 | train_loss: 0.4777 | train_acc: 0.8125 | test_loss: 1.0727 | test_acc: 0.4188
# Epoch: 35 | train_loss: 0.3501 | train_acc: 0.8729 | test_loss: 1.1753 | test_acc: 0.4188
# Epoch: 36 | train_loss: 0.3468 | train_acc: 0.8688 | test_loss: 1.3038 | test_acc: 0.4131
# Epoch: 37 | train_loss: 0.3641 | train_acc: 0.8375 | test_loss: 1.3316 | test_acc: 0.4074
# Epoch: 38 | train_loss: 0.3380 | train_acc: 0.8729 | test_loss: 1.3838 | test_acc: 0.3847
# Epoch: 39 | train_loss: 0.3025 | train_acc: 0.8833 | test_loss: 1.3495 | test_acc: 0.4040
# Epoch: 40 | train_loss: 0.2346 | train_acc: 0.9208 | test_loss: 1.5908 | test_acc: 0.4131

# %% [markdown]
# ## 8. Make a prediction on your own custom image of pizza/steak/sushi (you could even download one from the internet) with your trained model from exercise 7 and share your prediction.
# * Does the model you trained in exercise 7 get it right?
# * If not, what do you think you could do to improve it?
